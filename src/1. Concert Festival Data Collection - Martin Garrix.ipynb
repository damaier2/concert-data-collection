# %% [markdown]
# # Concert Festival - Data Collection
#
# <b> Author: </b> Derek A Maier | maierd@canisius.edu
#
# <hr>
#
# ## Scope:
#
# The scope of this workbook includes the following:
#
# - Data Collection from the Concert Festival data site
# - Data Manipulation / Cleansing for Analysis
# - Storage of the data collection above
#
# <hr>
#
# ## Assumptions:
#
# The development and execution of this workbook / analysis is based on the following assumptions (<i>check marks indicate the assumption has been met</i>):
#
# - <b> ✓ </b> Ethical ability to scrape the Concert Festival Site
# - <b> ✓ </b> Data availability of historical concert information for certain artists
#
# <hr>
#
# ## References:
#
# The data was provided by the following base site: https://www.concertarchives.org/
#
# The use case used for the dashboard analysis was Martin Garrix, whose base url was the following: https://www.concertarchives.org/bands/martin-garrix?page=1#concert-table
#
# <hr>

# %% [markdown]
# ## 1.a. Import Libraries & Set Global Variables

# %%
# Imports
import os
import pickle
import pandas as pd
from datetime import datetime

from dam.scrape import Engine # NOTE: This is a custom package I created for ethical hacking, simply replace with a GET request

# %%
# Global variables
data_dir = 'data/'
concert_collection_file = os.path.join(data_dir, 'martin_garrix_concert_collection.xlsx') # This will be our flat concert dataset
concert_set_collection_file = os.path.join(data_dir, 'martin_garrix_concert_set_collection.xlsx') # This will be our xref table for looking up concert sets to the concert ID in the dataset above

# %% [markdown]
# ## 1.b. Utility Functions to Parse the Target Site(s)

# %%
# Create all utility functions for parsing the desired content from our target site

# Step 1. Gather all concert specific data 
def parse_concert_details(url):

    """
    Description:
    ------------
    Parses all of individual concert details for the concert collection dataset
    
    Params:
    ------------
    url : (str)
        Represents the base url to scrape, or defaults to the static URL
        
    Returns
    ------------
    data : (list)
        Represents a list of dictionaries with key:value pairs of the parsed data elements 
    
    """
     
    data = []    
    engine = Engine()
    
    soup = None
    
    try:
        soup = engine.soup_request(url)
        main_div = soup.find("div", attrs={"class": "table-responsive"}) # Main container
        table_div = main_div.find("table") # Table container
        trs = table_div.find_all("tr")[1:] # Table rows
        
        for i in range(len(trs)):
            data.append({
                'concert_date': trs[i].find_all("td")[0].text.replace('\n', '').strip(),
                'concert_name': trs[i].find_all("td")[1].find('strong').text.replace('\n', '').strip(),
                'concert_link': "https://www.concertarchives.org" + trs[i].find_all("td")[1].find('a')['href'],
                'concert_venue_name': trs[i].find_all("td")[2].text.replace('\n', '').strip(),
                'concert_venue_link': "https://www.concertarchives.org" + trs[i].find_all("td")[2].find('a')['href'] if trs[i].find_all("td")[2].find('a') is not None else '',
                'concert_location_name': trs[i].find_all("td")[3].text.replace('\n', '').strip(),
                'concert_location_link': "https://www.concertarchives.org" + trs[i].find_all("td")[3].find('a')['href'] if trs[i].find_all("td")[3].find('a') is not None else ''
            })

    except:
        pass
    
    return data

# %% [markdown]
# ## 1.c. Gather & Dump the Concert Collection Data to Disk
#
# <b> Note: </b> We will loop through all of Base URL pages and execute the parsing function, because the base site data is paginated

# %%
# Artist of Interest
artist = "martin-garrix" # This represents the format of the artist in the URL string

# Total Pages for Martin Garrix
total_pages = 11

# Base URLs to Scrape
base_urls = [f'https://www.concertarchives.org/bands/{artist}?page={i}#concert-table' for i in range(total_pages+1)][1:]

# %%
print('The following links will be passed through our parsing function and appended to a master list of results\n' + '='*105)
base_urls
# Out:
# The following links will be passed through our parsing function and appended to a master list of results
# =========================================================================================================
# ['https://www.concertarchives.org/bands/martin-garrix?page=1#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=2#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=3#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=4#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=5#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=6#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=7#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=8#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=9#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=10#concert-table',
#  'https://www.concertarchives.org/bands/martin-garrix?page=11#concert-table']

# %%
# Master Results List 
concert_collection = []

# Loop through each URL and append results to master
for idx,url in enumerate(base_urls):
    # This is where our parsing function will go
    print(f'Collection Details for URL No. {idx} of {total_pages}')
    concert_collection += parse_concert_details(url)
# Out:
# Collection Details for URL No. 0 of 11
# Collection Details for URL No. 1 of 11
# Collection Details for URL No. 2 of 11
# Collection Details for URL No. 3 of 11
# Collection Details for URL No. 4 of 11
# Collection Details for URL No. 5 of 11
# Collection Details for URL No. 6 of 11
# Collection Details for URL No. 7 of 11
# Collection Details for URL No. 8 of 11
# Collection Details for URL No. 9 of 11
# Collection Details for URL No. 10 of 11
# Timeout Error: HTTPSConnectionPool(host='www.concertarchives.org', port=443): Read timed out. (read timeout=5)

# %%
print(f'The total number of records of this dataset: {len(concert_collection)}')
concert_collection
# Out:
# The total number of records of this dataset: 500
# [{'concert_date': 'Jul 30, 2020–Aug 02, 2020',
#   'concert_name': 'Untold Festival 2020',
#   'concert_link': 'https://www.concertarchives.org/concerts/untold-festival-2020',
#   'concert_venue_name': 'Cluj Arena',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/cluj-arena',
#   'concert_location_name': 'Cluj-Napoca, Romania',
#   'concert_location_link': 'https://www.concertarchives.org/locations/cluj-napoca-romania'},
#  {'concert_date': 'Feb 23, 2020–Feb 23, 2020',
#   'concert_name': 'Carnaval do B.E.M 2020',
#   'concert_link': 'https://www.concertarchives.org/concerts/carnaval-do-b-e-m-2020',
#   'concert_venue_name': 'Estádio do Mineirão',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/estadio-do-mineirao-e9b6b8e4-9c91-48e0-882a-6e8b9e425ad5',
#   'concert_location_name': 'Belo Horizonte, Brazil',
#   'concert_location_link': 'https://www.concertarchives.org/locations/belo-horizonte-brazil'},
#  {'concert_date': 'Feb 22, 2020–Feb 23, 2020',
#   'concert_name': 'Carnaval Maori 10 anos • Martin Garrix 2020',
#   'concert_link': 'https://www.concertarchives.org/concerts/carnaval-maori-10-anos-martin-garrix-2020',
#   'concert_venue_name': 'Maori Beach Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/maori-beach-club-3ac8f990-d853-4c8c-86ec-d2a6ccf8ec45',
#   'concert_location_name': 'Porto Alegre, Brazil',
#   'concert_location_link': 'https://www.concertarchives.org/locations/porto-alegre-brazil'},
#  {'concert_date': 'Feb 21, 2020',
#   'concert_name': 'Carnaval Maori 10 Anos',
#   'concert_link': 'https://www.concertarchives.org/concerts/carnaval-maori-10-anos',
#   'concert_venue_name': 'Maori Beach Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/maori-beach-club-91a2f751-7670-4dbf-bc35-eaae1e863112',
#   'concert_location_name': 'Xangri-lá, Brazil',
#   'concert_location_link': 'https://www.concertarchives.org/locations/xangri-la-brazil'},
#  {'concert_date': 'Feb 01, 2020',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-8d440d0d-bbd5-4d44-a120-743556ca74df',
#   'concert_venue_name': 'DAER Dayclub South Florida',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/daer-dayclub-south-florida',
#   'concert_location_name': 'Fort Lauderdale, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/fort-lauderdale-fl'},
#  {'concert_date': 'Dec 27, 2019–Dec 29, 2019',
#   'concert_name': 'Sunburn Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sunburn-festival-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Pune, India',
#   'concert_location_link': 'https://www.concertarchives.org/locations/pune-india'},
#  {'concert_date': 'Dec 20, 2019–Dec 21, 2019',
#   'concert_name': 'Paradise Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/paradise-festival-2019',
#   'concert_venue_name': 'Playa Juanillo',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/playa-juanillo',
#   'concert_location_name': 'Higüey, Dominican Republic',
#   'concert_location_link': 'https://www.concertarchives.org/locations/higuey-dominican-republic'},
#  {'concert_date': 'Dec 14, 2019–Dec 15, 2019',
#   'concert_name': 'Wildbeat 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/wildbeat-2019',
#   'concert_venue_name': 'Dajia Riverside Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/dajia-riverside-park',
#   'concert_location_name': 'Taipei, Taiwan',
#   'concert_location_link': 'https://www.concertarchives.org/locations/taipei-taiwan'},
#  {'concert_date': 'Dec 13, 2019–Dec 15, 2019',
#   'concert_name': 'Djakarta Warehouse Project 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/djakarta-warehouse-project-2019',
#   'concert_venue_name': 'Jakarta International Expo (JIExpo)',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/jakarta-international-expo-jiexpo',
#   'concert_location_name': 'Jakarta, Indonesia',
#   'concert_location_link': 'https://www.concertarchives.org/locations/jakarta-indonesia'},
#  {'concert_date': 'Nov 23, 2019–Nov 24, 2019',
#   'concert_name': 'Medusa SunBeach 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/medusa-sunbeach-2019',
#   'concert_venue_name': 'Campo Marte',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/campo-marte',
#   'concert_location_name': 'Mexico City, Mexico',
#   'concert_location_link': 'https://www.concertarchives.org/locations/mexico-city-mexico--3'},
#  {'concert_date': 'Nov 22, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-335bd8be-4e98-40d2-8010-910f88fd4497',
#   'concert_venue_name': 'The City Nightclub Cancun',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-city-nightclub-cancun',
#   'concert_location_name': 'Cancun, Mexico',
#   'concert_location_link': 'https://www.concertarchives.org/locations/cancun-mexico'},
#  {'concert_date': 'Nov 16, 2019–Nov 17, 2019',
#   'concert_name': 'Dreamfields Mexico 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/dreamfields-mexico-2019',
#   'concert_venue_name': 'Explanada Estadio Akron',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/explanada-estadio-akron-72da37b7-c3a6-4b20-b549-b66f893b406c',
#   'concert_location_name': 'Guadalajara, Mexico',
#   'concert_location_link': 'https://www.concertarchives.org/locations/guadalajara-mexico'},
#  {'concert_date': 'Nov 01, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-370f9127-f143-4bd1-b7c9-1092165c341e',
#   'concert_venue_name': 'One Third',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/one-third',
#   'concert_location_name': 'Beijing, China',
#   'concert_location_link': 'https://www.concertarchives.org/locations/beijing-china'},
#  {'concert_date': 'Oct 26, 2019',
#   'concert_name': 'Freaky Deaky',
#   'concert_link': 'https://www.concertarchives.org/concerts/freaky-deaky-15b3e7e1-27ce-4ee9-a2d2-efdd26a855bd',
#   'concert_venue_name': 'Houston Raceway Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/houston-raceway-park-75d1e11f-bf0c-49dc-817c-6087792bd49a',
#   'concert_location_name': 'Baytown, TX',
#   'concert_location_link': 'https://www.concertarchives.org/locations/baytown-tx-da9b7e7a-a9e1-4724-b003-801c7bbae141'},
#  {'concert_date': 'Oct 25, 2019',
#   'concert_name': 'Cosmic Gate / Martin Garrix / Sam Feldt',
#   'concert_link': 'https://www.concertarchives.org/concerts/cosmic-gate-martin-garrix-sam-feldt',
#   'concert_venue_name': 'Pacific Coliseum',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/pacific-coliseum',
#   'concert_location_name': 'Vancouver, BC',
#   'concert_location_link': 'https://www.concertarchives.org/locations/vancouver-bc'},
#  {'concert_date': 'Oct 19, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-e16eec3d-2792-44cd-b14c-98cef0c974d0',
#   'concert_venue_name': 'Amsterdam RAI',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/amsterdam-rai',
#   'concert_location_name': 'Amsterdam, NL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/amsterdam-netherlands'},
#  {'concert_date': 'Oct 18, 2019',
#   'concert_name': 'Martin Garrix / Dyro',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-dyro',
#   'concert_venue_name': 'Amsterdam RAI',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/amsterdam-rai',
#   'concert_location_name': 'Amsterdam, NL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/amsterdam-netherlands'},
#  {'concert_date': 'Oct 18, 2019',
#   'concert_name': 'Martin Garrix: ADE 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-ade-2019',
#   'concert_venue_name': 'Amsterdam RAI',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/amsterdam-rai',
#   'concert_location_name': 'Amsterdam, NL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/amsterdam-netherlands'},
#  {'concert_date': 'Oct 03, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-100bed8b-bb29-4f5b-bab7-04f29d6711a6',
#   'concert_venue_name': 'Echostage',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/echostage',
#   'concert_location_name': 'Washington, D.C.',
#   'concert_location_link': 'https://www.concertarchives.org/locations/washington-d-c'},
#  {'concert_date': 'Oct 02, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-3bdb602a-fbd9-475d-b6ff-feebeed7d461',
#   'concert_venue_name': 'Glow at Echostage',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/glow-at-echostage--2',
#   'concert_location_name': 'Washington, D.C.',
#   'concert_location_link': 'https://www.concertarchives.org/locations/washington-d-c'},
#  {'concert_date': 'Sep 28, 2019',
#   'concert_name': 'Martin Garrix / PAZ / Matt Ox',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-paz-matt-ox',
#   'concert_venue_name': 'Wells Fargo Center',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/wells-fargo-center--2',
#   'concert_location_name': 'Philadelphia, PA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/philadelphia-pa'},
#  {'concert_date': 'Sep 27, 2019–Oct 01, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-8bcb59b7-f368-4ff8-b2c4-c7efc510ccf8',
#   'concert_venue_name': 'The Armory',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-armory--7',
#   'concert_location_name': 'Minneapolis, MN',
#   'concert_location_link': 'https://www.concertarchives.org/locations/minneapolis-mn'},
#  {'concert_date': 'Sep 27, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-2ccccbed-7878-4960-a29e-049bc0098e7e',
#   'concert_venue_name': 'The Armory',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-armory--7',
#   'concert_location_name': 'Minneapolis, MN',
#   'concert_location_link': 'https://www.concertarchives.org/locations/minneapolis-mn'},
#  {'concert_date': 'Sep 07, 2019–Sep 08, 2019',
#   'concert_name': 'Lollapalooza Berlin 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/lollapalooza-berlin-2019-ee5617bd-e0de-4d12-b19f-bdf0530c8537',
#   'concert_venue_name': 'Olympiastadion & Olympiapark Berlin',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/olympiastadion-olympiapark-berlin',
#   'concert_location_name': 'Berlin, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/berlin-germany--2'},
#  {'concert_date': 'Sep 07, 2019–Sep 08, 2019',
#   'concert_name': 'Lollapalooza Berlin 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/lollapalooza-berlin-2019',
#   'concert_venue_name': 'Olympia Stadion',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/olympia-stadion--2',
#   'concert_location_name': 'Berlin, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/berlin-germany--2'},
#  {'concert_date': 'Sep 07, 2019–Sep 08, 2019',
#   'concert_name': 'Lollapalooza',
#   'concert_link': 'https://www.concertarchives.org/concerts/lollapalooza-186b9331-0a7d-45fb-bb37-6c525e50f3a9',
#   'concert_venue_name': 'Olympiastadion',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/olympiastadion--16',
#   'concert_location_name': 'Berlin, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/berlin-germany--2'},
#  {'concert_date': 'Aug 29, 2019',
#   'concert_name': 'Dyro / Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/dyro-martin-garrix',
#   'concert_venue_name': 'Ushuaia Ibiza Beach Hotel',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-ibiza-beach-hotel--2',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Aug 24, 2019',
#   'concert_name': 'SW4 2019 - Saturday',
#   'concert_link': 'https://www.concertarchives.org/concerts/sw4-2019-friday',
#   'concert_venue_name': 'Clapham Common',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/clapham-common',
#   'concert_location_name': 'London, UK',
#   'concert_location_link': 'https://www.concertarchives.org/locations/london-uk--2'},
#  {'concert_date': 'Aug 23, 2019–Aug 25, 2019',
#   'concert_name': 'Mysteryland 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/mysteryland-2019',
#   'concert_venue_name': 'Mysteryland Festival',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/mysteryland-festival',
#   'concert_location_name': 'Haarlemmermeer, Netherlands',
#   'concert_location_link': 'https://www.concertarchives.org/locations/haarlemmermeer-netherlands'},
#  {'concert_date': 'Aug 21, 2019–Aug 25, 2019',
#   'concert_name': 'New Horizons 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/new-horizons-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Nürburg, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/nurburg-germany'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-festival-2019',
#   'concert_venue_name': 'Óbudai-sziget',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/obudai-sziget',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-af21da66-1676-4caf-be18-617abd011a7a',
#   'concert_venue_name': 'Sziget Island of Freedom',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/sziget-island-of-freedom--2',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-999772f4-5d9f-4ebe-b52b-fb19b49deef2',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Budapest',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-2683f8dc-70a9-4288-8f0d-082e7e305f57'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019-45578d2d-81d0-4f61-b6fb-4477a8ed0180',
#   'concert_venue_name': 'Óbudai-Sziget',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/obudai-sziget-3471bf42-c3dd-4a03-b58e-72f2a704089a',
#   'concert_location_name': 'Budapest, HU',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hu'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019-8e4a2fe2-b38d-4a70-b295-1dfd7814704f',
#   'concert_venue_name': 'Sziget Festival',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/sziget-festival--2',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019-3fe96cbc-188e-4da0-a03d-b4b591fb465c',
#   'concert_venue_name': 'Sziget',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/sziget',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019-fa6cfad8-684a-44b5-b166-f6751b317982',
#   'concert_venue_name': 'Sziget Island of Freedom',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/sziget-island-of-freedom--2',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019',
#   'concert_venue_name': 'Sziget Island of Freedom',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/sziget-island-of-freedom--2',
#   'concert_location_name': 'Budapest, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest-hungary'},
#  {'concert_date': 'Aug 07, 2019–Aug 13, 2019',
#   'concert_name': 'Sziget 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sziget-2019-f1d45035-3d05-4063-bc2f-9161fae02a0c',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Budapest,',
#   'concert_location_link': 'https://www.concertarchives.org/locations/budapest'},
#  {'concert_date': 'Aug 02, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-575f7a0f-356f-4502-9de0-6e765b866589',
#   'concert_venue_name': 'Ushuaia',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-925cc3ae-e3ee-441b-9285-80845d7973c8',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Aug 01, 2019–Aug 04, 2019',
#   'concert_name': 'Untold Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/untold-festival-2019',
#   'concert_venue_name': 'Aleea Stadionului',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/aleea-stadionului',
#   'concert_location_name': 'Cluj-Napoca, Romania',
#   'concert_location_link': 'https://www.concertarchives.org/locations/cluj-napoca-romania'},
#  {'concert_date': 'Jul 26, 2019–Jul 28, 2019',
#   'concert_name': 'Fuji Rock 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/fuji-rock-2019-8b4c951c-89e2-40b9-9be2-656903299ad0',
#   'concert_venue_name': 'Naeba Ski Resort',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/naeba-ski-resort-0b000e67-dd07-4bc2-9ffb-0244769bb239',
#   'concert_location_name': 'Niigata, Japan',
#   'concert_location_link': 'https://www.concertarchives.org/locations/niigata-japan'},
#  {'concert_date': 'Jul 25, 2019',
#   'concert_name': 'Dubvision / Vintage Culture / Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/dubvision-vintage-culture-martin-garrix',
#   'concert_venue_name': 'Ushuaia',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-925cc3ae-e3ee-441b-9285-80845d7973c8',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Jul 20, 2019–Jul 21, 2019',
#   'concert_name': 'Lollapalooza Paris 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/lollapalooza-paris-2019',
#   'concert_venue_name': 'Hippodrome Longchamp',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/hippodrome-longchamp',
#   'concert_location_name': 'Paris, FR',
#   'concert_location_link': 'https://www.concertarchives.org/locations/paris-fr'},
#  {'concert_date': 'Jul 20, 2019–Jul 21, 2019',
#   'concert_name': 'Lollapalooza Paris 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/lollapalooza-2019-874d2a9b-13e7-4a08-b7e8-3bd53a09dcbe',
#   'concert_venue_name': 'Hippodrome de Longchamp',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/hippodrome-de-longchamp--3',
#   'concert_location_name': 'Paris, France',
#   'concert_location_link': 'https://www.concertarchives.org/locations/paris-france'},
#  {'concert_date': 'Jul 18, 2019–Jul 21, 2019',
#   'concert_name': 'Les vieilles Charrues 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/les-vieilles-charrues-2019',
#   'concert_venue_name': 'Festival Les Vieilles Charrues',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/festival-les-vieilles-charrues',
#   'concert_location_name': 'Carhaix, France',
#   'concert_location_link': 'https://www.concertarchives.org/locations/carhaix-france'},
#  {'concert_date': 'Jul 10, 2019–Jul 14, 2019',
#   'concert_name': 'Airbeat One Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/airbeat-one-festival-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Schwerin, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/schwerin-germany'},
#  {'concert_date': 'Jul 09, 2019–Jul 09, 2019',
#   'concert_name': 'Isle Of MTV 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/isle-of-mtv-2019',
#   'concert_venue_name': 'The Granaries Il-Fosos',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-granaries-il-fosos',
#   'concert_location_name': 'Valletta, Malta',
#   'concert_location_link': 'https://www.concertarchives.org/locations/valletta-malta'},
#  {'concert_date': 'Jul 05, 2019–Jul 07, 2019',
#   'concert_name': 'Main Square Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/main-square-festival-2019',
#   'concert_venue_name': 'Camping Main Square Festival',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/camping-main-square-festival',
#   'concert_location_name': 'Arras, France',
#   'concert_location_link': 'https://www.concertarchives.org/locations/arras-france'},
#  {'concert_date': 'Jun 22, 2019–Jun 23, 2019',
#   'concert_name': 'Escapade Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/escapade-festival-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Ottawa, ON',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ottawa-on'},
#  {'concert_date': 'Jun 08, 2019–Jun 09, 2019',
#   'concert_name': 'Ultra Singapore 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/ultra-singapore-2019',
#   'concert_venue_name': 'Ultra Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ultra-park',
#   'concert_location_name': 'Singapore, Singapore',
#   'concert_location_link': 'https://www.concertarchives.org/locations/singapore-singapore'},
#  {'concert_date': 'Jun 07, 2019–Jun 09, 2019',
#   'concert_name': 'Ultra Korea 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/ultra-korea-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Seoul, Korea, Republic Of',
#   'concert_location_link': 'https://www.concertarchives.org/locations/seoul-korea-republic-of'},
#  {'concert_date': 'May 17, 2019–May 19, 2019',
#   'concert_name': 'EDC Last Vegas 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/edc-last-vegas-2019',
#   'concert_venue_name': 'Las Vegas Motor Speedway',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/las-vegas-motor-speedway',
#   'concert_location_name': 'Las Vegas, NV',
#   'concert_location_link': 'https://www.concertarchives.org/locations/las-vegas-nv'},
#  {'concert_date': 'May 17, 2019–May 19, 2019',
#   'concert_name': 'EDC Las Vegas 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/edc-las-vegas-2019',
#   'concert_venue_name': 'Las Vegas Motor Speedway',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/las-vegas-motor-speedway',
#   'concert_location_name': 'Las Vegas, NV',
#   'concert_location_link': 'https://www.concertarchives.org/locations/las-vegas-nv'},
#  {'concert_date': 'May 10, 2019–May 11, 2019',
#   'concert_name': 'Shaky Beats Music Festival 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/shaky-beats-music-festival-2019',
#   'concert_venue_name': 'Central Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/central-park',
#   'concert_location_name': 'Atlanta, GA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/atlanta-ga'},
#  {'concert_date': 'Apr 06, 2019',
#   'concert_name': 'Beyond Wonderland / Jerry David Decicca / Above & Beyond / Alesso / Boombox Cartel / Bruno Martini / Claptone / Code Black / Dillon Francis / Ekali / Joyryde / Junkie Kid / Lady Faith / Latmun / Lemarroy / Martin Garrix / Melé / noisecontrollers /...',
#   'concert_link': 'https://www.concertarchives.org/concerts/beyond-wonderland-jerry-david-decicca-above-beyond-alesso-boombox-cartel-bruno-martini-claptone-code-black-dillon-francis-ekali-joyryde-junkie-kid-lady-faith-latmun-lemarroy-martin-garrix-mele-noisecontrollers',
#   'concert_venue_name': 'Parque Fundidora',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/parque-fundidora-e769c304-fd1b-4918-b3a4-8d1983052ca2',
#   'concert_location_name': 'Monterrey, Mexico',
#   'concert_location_link': 'https://www.concertarchives.org/locations/monterrey-mexico-37783dad-6aa1-41c8-a5e8-a72a49f8c09f'},
#  {'concert_date': 'Mar 29, 2019–Mar 31, 2019',
#   'concert_name': '2019 Ultra Music Festival Miami',
#   'concert_link': 'https://www.concertarchives.org/concerts/2019-ultra-music-festival-miami',
#   'concert_venue_name': 'Virginia Key Beach Park & Miami Marine Stadium',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/virginia-key-beach-park-miami-marine-stadium',
#   'concert_location_name': 'Miami, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/miami-fl'},
#  {'concert_date': 'Mar 09, 2019–Mar 16, 2019',
#   'concert_name': 'Tomorrowland Winter 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/tomorrowland-winter-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Grenoble, France',
#   'concert_location_link': 'https://www.concertarchives.org/locations/grenoble-france'},
#  {'concert_date': 'Feb 24, 2019–Feb 24, 2019',
#   'concert_name': 'Ultra Australia 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/ultra-australia-2019-27dbd02f-b9a3-4d7a-aeb6-fb2391a74fe4',
#   'concert_venue_name': 'Parramatta Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/parramatta-park--4',
#   'concert_location_name': 'Sydney, NSW',
#   'concert_location_link': 'https://www.concertarchives.org/locations/sydney-nsw'},
#  {'concert_date': 'Feb 23, 2019–Feb 23, 2019',
#   'concert_name': 'Ultra Australia 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/ultra-australia-2019',
#   'concert_venue_name': 'Flemington Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flemington-racecourse--10',
#   'concert_location_name': 'Melbourne, VIC',
#   'concert_location_link': 'https://www.concertarchives.org/locations/melbourne-vic'},
#  {'concert_date': 'Jan 31, 2019',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-9eae5e6a-f1e0-40ce-b0ab-94039b6d36b2',
#   'concert_venue_name': 'Belly Up Aspen',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/belly-up-aspen-be45ee55-106b-4a7f-a827-a7c7352dee00',
#   'concert_location_name': 'Denver, CO',
#   'concert_location_link': 'https://www.concertarchives.org/locations/denver-co'},
#  {'concert_date': 'Jan 20, 2019–Jan 20, 2019',
#   'concert_name': 'Sound & Snow Festival Gastein 2019',
#   'concert_link': 'https://www.concertarchives.org/concerts/sound-snow-festival-gastein-2019',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Worgl, Austria',
#   'concert_location_link': 'https://www.concertarchives.org/locations/worgl-austria'},
#  {'concert_date': 'Dec 27, 2018–Dec 31, 2018',
#   'concert_name': 'ISY Music Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/isy-music-festival-2018-7e8a4b62-716e-48b9-9153-7758f8d39d00',
#   'concert_venue_name': 'ISY Sanya International Music Festival',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/isy-sanya-international-music-festival',
#   'concert_location_name': 'Sanya, China',
#   'concert_location_link': 'https://www.concertarchives.org/locations/sanya-china'},
#  {'concert_date': 'Dec 15, 2018–Dec 16, 2018',
#   'concert_name': 'Creamfields Hong Kong 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/creamfields-hong-kong-2018-cb856cab-689f-4ef4-9bef-87f95f01aaab',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Hong Kong, China',
#   'concert_location_link': 'https://www.concertarchives.org/locations/hong-kong-china'},
#  {'concert_date': 'Dec 08, 2018–Dec 09, 2018',
#   'concert_name': 'Electric Jungle Music Fesitval 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/electric-jungle-music-fesitval-2018',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Foshan, China',
#   'concert_location_link': 'https://www.concertarchives.org/locations/foshan-china'},
#  {'concert_date': 'Nov 11, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-98640ff0-654c-4eb7-9c65-be94c8f88114',
#   'concert_venue_name': 'Coliseo Ditaires',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/coliseo-ditaires',
#   'concert_location_name': 'Medellín, Colombia',
#   'concert_location_link': 'https://www.concertarchives.org/locations/medellin-colombia--2'},
#  {'concert_date': 'Nov 10, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-bcd575a7-35f2-47e0-b75c-08518811e9c3',
#   'concert_venue_name': 'Centro de Eventos Autopista Norte',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/centro-de-eventos-autopista-norte',
#   'concert_location_name': 'Bogota, Colombia',
#   'concert_location_link': 'https://www.concertarchives.org/locations/bogota-colombia-54e2b9dc-f741-41f0-8630-cb3b71fc9c13'},
#  {'concert_date': 'Nov 09, 2018–Nov 10, 2018',
#   'concert_name': 'EDC Orlando',
#   'concert_link': 'https://www.concertarchives.org/concerts/edc-orlando',
#   'concert_venue_name': 'Tinker Field',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/tinker-field--3',
#   'concert_location_name': '',
#   'concert_location_link': ''},
#  {'concert_date': 'Oct 26, 2018–Dec 27, 2018',
#   'concert_name': 'Escape: Psycho Circus 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/escape-psycho-circus-2018',
#   'concert_venue_name': 'National Orange Show Events Center',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/national-orange-show-events-center',
#   'concert_location_name': 'San Bernardino, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/san-bernardino-ca'},
#  {'concert_date': 'Oct 26, 2018–Oct 28, 2018',
#   'concert_name': 'Voodoo Fest',
#   'concert_link': 'https://www.concertarchives.org/concerts/voodoo-fest--7',
#   'concert_venue_name': 'City Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/city-park',
#   'concert_location_name': 'New Orleans, LA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/new-orleans-la'},
#  {'concert_date': 'Oct 19, 2018',
#   'concert_name': 'Martin Garrix 18+',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-brooks-loopers',
#   'concert_venue_name': 'Rai',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/rai',
#   'concert_location_name': 'Amsterdam, NL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/amsterdam-netherlands'},
#  {'concert_date': 'Sep 15, 2018–Sep 16, 2018',
#   'concert_name': 'Creamfields Taiwan 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/creamfields-taiwan-2018',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Taipei, Taiwan',
#   'concert_location_link': 'https://www.concertarchives.org/locations/taipei-taiwan'},
#  {'concert_date': 'Aug 31, 2018–Sep 02, 2018',
#   'concert_name': 'Electric Zoo 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/electric-zoo-2018',
#   'concert_venue_name': "Randall's Island Park",
#   'concert_venue_link': 'https://www.concertarchives.org/venues/randall-s-island-park',
#   'concert_location_name': 'New York, NY',
#   'concert_location_link': 'https://www.concertarchives.org/locations/new-york-ny--3'},
#  {'concert_date': 'Aug 31, 2018–Sep 02, 2018',
#   'concert_name': 'Electric Zoo 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/marshmello-virtual-self-san-holo-kill-the-noise-crankdat-jauz-martin-garrix-kaskade-alan-walker-cash-cash-bonnie-x-clyde-tiesto-alesso',
#   'concert_venue_name': "Randall's Island Park",
#   'concert_venue_link': 'https://www.concertarchives.org/venues/randall-s-island-park',
#   'concert_location_name': 'New York, NY',
#   'concert_location_link': 'https://www.concertarchives.org/locations/new-york-ny--3'},
#  {'concert_date': 'Aug 30, 2018–Sep 01, 2018',
#   'concert_name': 'Electric Zoo',
#   'concert_link': 'https://www.concertarchives.org/concerts/electric-zoo--3',
#   'concert_venue_name': "Randall's Island",
#   'concert_venue_link': 'https://www.concertarchives.org/venues/randall-s-island--2',
#   'concert_location_name': 'New York, NY',
#   'concert_location_link': 'https://www.concertarchives.org/locations/new-york-ny--3'},
#  {'concert_date': 'Aug 25, 2018',
#   'concert_name': 'Martin Garrix / Zara Larsson',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-zara-larsson',
#   'concert_venue_name': 'Boucher Playing Fields',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/boucher-playing-fields-3ca5867c-8d62-4197-9073-9b5d6d802e3b',
#   'concert_location_name': 'Belfast, UK',
#   'concert_location_link': 'https://www.concertarchives.org/locations/belfast-uk'},
#  {'concert_date': 'Aug 23, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-b998ad35-ee08-4eba-8360-f8206aa45fb6',
#   'concert_venue_name': 'Ushuaïa Ibiza',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-ibiza',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Aug 17, 2018–Aug 18, 2018',
#   'concert_name': 'Kraków Live Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/krakow-live-festival-2018',
#   'concert_venue_name': 'Lotnisko - Muzeum Lotnictwa',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/lotnisko-muzeum-lotnictwa--2',
#   'concert_location_name': 'Krakow, Poland',
#   'concert_location_link': 'https://www.concertarchives.org/locations/krakow-poland'},
#  {'concert_date': 'Aug 16, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-73ae3a7b-e06a-4c29-9c61-86fb978de8a3',
#   'concert_venue_name': 'Ushuaïa Ibiza',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-ibiza',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Aug 09, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-96bc962a-8db6-471d-8f05-0fbefa1a689c',
#   'concert_venue_name': 'Ushuaïa Ibiza',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-ibiza',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Aug 04, 2018',
#   'concert_name': 'Space Jesus / Cash Cash / Malaa / Borgore / Black Tiger Sex Machine / Martin Garrix / Brohug / Dirt Monkey / RL Grime / Whipped Cream / Bro Safari / BLU J / Mija / Zaxx / Ookay / Kaskade / Tigerlily / Eprom / Win and Woo / Skiitour / KUURO / Dillo...',
#   'concert_link': 'https://www.concertarchives.org/concerts/space-jesus-cash-cash-malaa-borgore-black-tiger-sex-machine-martin-garrix-brohug-dirt-monkey-rl-grime-whipped-cream-bro-safari-blu-j-mija-zaxx-ookay-kaskade-tigerlily-eprom-win-and-woo-skiitour-kuuro-dillo',
#   'concert_venue_name': 'The HiFi Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-hifi-club-0a16eea4-e6c0-4187-9a6f-4b1dc2f30cd3',
#   'concert_location_name': 'Calgary, AB',
#   'concert_location_link': 'https://www.concertarchives.org/locations/calgary-ab--2'},
#  {'concert_date': 'Aug 04, 2018 –Aug 05, 2018',
#   'concert_name': 'VELD 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/veld-2018',
#   'concert_venue_name': 'Downsview Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/downsview-park',
#   'concert_location_name': 'Toronto, ON',
#   'concert_location_link': 'https://www.concertarchives.org/locations/toronto-on'},
#  {'concert_date': 'Jul 29, 2018',
#   'concert_name': 'Tomorrowland 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/tomorrowland-2018',
#   'concert_venue_name': 'Tomorrowland',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/tomorrowland--2',
#   'concert_location_name': 'Boom, Belgium',
#   'concert_location_link': 'https://www.concertarchives.org/locations/boom-belgium'},
#  {'concert_date': 'Jul 27, 2018–Jul 27, 2018',
#   'concert_name': 'Martin Garrix - Universal Music Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-universal-music-festival-2018',
#   'concert_venue_name': 'Teatro Real',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/teatro-real',
#   'concert_location_name': 'Madrid, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/madrid-spain'},
#  {'concert_date': 'Jul 19, 2018–Jul 22, 2018',
#   'concert_name': 'Parookaville Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/parookaville-festival-2018',
#   'concert_venue_name': 'Airport, Weeze',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/airport-weeze',
#   'concert_location_name': 'Weeze, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/weeze-germany'},
#  {'concert_date': 'Jul 19, 2018–Jul 22, 2018',
#   'concert_name': 'Tomorrowland 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/tomorrowland-2018-36ebdb28-4879-4ffe-887a-fb2bc2a7a01e',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Boom, BE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/boom-be'},
#  {'concert_date': 'Jul 12, 2018–Jul 14, 2018',
#   'concert_name': 'Electrobeach Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/electrobeach-festival-2018',
#   'concert_venue_name': 'Avenue du Paquebot des Sables',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/avenue-du-paquebot-des-sables-9c87ebd6-d82d-49d4-bcdc-5c7d9371a71e',
#   'concert_location_name': 'Le Barcarès',
#   'concert_location_link': 'https://www.concertarchives.org/locations/le-barcares'},
#  {'concert_date': 'Jul 12, 2018–Jul 15, 2018',
#   'concert_name': 'Exit Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/exit-festival-2018',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Novi Sad, Serbia',
#   'concert_location_link': 'https://www.concertarchives.org/locations/novi-sad-serbia'},
#  {'concert_date': 'Jul 06, 2018–Jul 08, 2018',
#   'concert_name': 'We Are Electric Weekender',
#   'concert_link': 'https://www.concertarchives.org/concerts/we-are-electric-weekender--2',
#   'concert_venue_name': 'Velder Woods',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/velder-woods',
#   'concert_location_name': 'Boxtel',
#   'concert_location_link': 'https://www.concertarchives.org/locations/boxtel'},
#  {'concert_date': 'Jul 05, 2018',
#   'concert_name': 'Martin Garrix / Droeloe / Justin Mylo / CMC$',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-droeloe-justin-mylo-cmc',
#   'concert_venue_name': 'Ushuaia Ibiza Beach Hotel',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ushuaia-ibiza-beach-hotel--2',
#   'concert_location_name': 'Ibiza, Spain',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ibiza-spain'},
#  {'concert_date': 'Jul 04, 2018–Jul 08, 2018',
#   'concert_name': 'Balaton Sound 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/balaton-sound-2018',
#   'concert_venue_name': 'Balaton Sound',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/balaton-sound',
#   'concert_location_name': 'Zamárdi, Hungary',
#   'concert_location_link': 'https://www.concertarchives.org/locations/zamardi-hungary'},
#  {'concert_date': 'Jul 04, 2018–Jul 07, 2018',
#   'concert_name': 'Atlas Weekend 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/atlas-weekend-2018--2',
#   'concert_venue_name': 'Expocenter of Ukraine (VDNH) / Експоцентр України (ВДНГ)',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/expocenter-of-ukraine-vdnh--2',
#   'concert_location_name': 'Kyiv, Ukraine',
#   'concert_location_link': 'https://www.concertarchives.org/locations/kyiv-ukraine'},
#  {'concert_date': 'Jul 04, 2018–Jul 08, 2018',
#   'concert_name': 'Atlas Weekend 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/atlas-weekend-2018',
#   'concert_venue_name': 'Expocenter of Ukraine (VDNH) / Експоцентр України (ВДНГ)',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/expocenter-of-ukraine-vdnh--2',
#   'concert_location_name': 'Kyiv, Ukraine',
#   'concert_location_link': 'https://www.concertarchives.org/locations/kyiv-ukraine'},
#  {'concert_date': 'Jun 28, 2018–Jun 30, 2018',
#   'concert_name': 'O Son do Camiño 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/o-son-do-camino-2018--2',
#   'concert_venue_name': 'Monte Do Gozo',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/monte-do-gozo--2',
#   'concert_location_name': 'Santiago de Compostela,',
#   'concert_location_link': 'https://www.concertarchives.org/locations/santiago-de-compostela'},
#  {'concert_date': 'Jun 19, 2018–Jul 27, 2018',
#   'concert_name': 'Milano Summer Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/milano-summer-festival-2018',
#   'concert_venue_name': 'Ippodromo Snai San Siro',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/ippodromo-snai-san-siro',
#   'concert_location_name': 'Milan, Italy',
#   'concert_location_link': 'https://www.concertarchives.org/locations/milan-italy'},
#  {'concert_date': 'Jun 16, 2018',
#   'concert_name': 'Firefly',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-2fa3bdfa-3a63-4b8d-84ca-cdffc7a10f03',
#   'concert_venue_name': 'The Woodlands',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-woodlands--3',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 14, 2018–Jun 17, 2018',
#   'concert_name': 'Firefly Music Festival',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival--79',
#   'concert_venue_name': 'Woodlands of Dover',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/woodlands-of-dover--2',
#   'concert_location_name': 'Dover De',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de--2'},
#  {'concert_date': 'Jun 14, 2018–Jun 17, 2018',
#   'concert_name': 'Firefly Music Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival-2018--9',
#   'concert_venue_name': 'The Woodlands, Dover International Speedway',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-woodlands-dover-international-speedway--3',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 14, 2018–Jun 16, 2018',
#   'concert_name': 'Firefly music festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival-2018-00a2c0d4-3188-47d8-b9c5-6a78ffc3861e',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 14, 2018–Jun 17, 2018',
#   'concert_name': 'Firefly Music Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival-2018--7',
#   'concert_venue_name': 'The Woodlands @ Dover International Speedway',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-woodlands-dover-international-speedway',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 14, 2018–Jun 16, 2018',
#   'concert_name': 'Firefly music festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival-2018-00a2c0d4-3188-47d8-b9c5-6a78ffc3861e',
#   'concert_venue_name': '',
#   'concert_venue_link': '',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 14, 2018–Jun 17, 2018',
#   'concert_name': 'Firefly Music Festival 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/firefly-music-festival-2018--9',
#   'concert_venue_name': 'The Woodlands, Dover International Speedway',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/the-woodlands-dover-international-speedway--3',
#   'concert_location_name': 'Dover, DE',
#   'concert_location_link': 'https://www.concertarchives.org/locations/dover-de'},
#  {'concert_date': 'Jun 01, 2018–Jun 03, 2018',
#   'concert_name': 'World Club Dome 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/world-club-dome-2018',
#   'concert_venue_name': 'Commerzbank Arena',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/commerzbank-arena-aa0541e8-4eda-47e6-aab9-466dda37bfe6',
#   'concert_location_name': 'Frankfurt, Germany',
#   'concert_location_link': 'https://www.concertarchives.org/locations/frankfurt-germany'},
#  {'concert_date': 'May 12, 2018–May 13, 2018',
#   'concert_name': 'EDC Japan 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/edc-japan-2018',
#   'concert_venue_name': 'ZOZO Marine Stadium & Makuhari Beach Park',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/zozo-marine-stadium-makuhari-beach-park',
#   'concert_location_name': 'Tokyo, Japan',
#   'concert_location_link': 'https://www.concertarchives.org/locations/tokyo-japan'},
#  {'concert_date': 'May 11, 2018',
#   'concert_name': 'Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-bdc57136-a41b-4451-a0a8-fbfcacbf0c5b',
#   'concert_venue_name': 'Club Cubic, City of Dreams',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/club-cubic-city-of-dreams',
#   'concert_location_name': 'Macau, China',
#   'concert_location_link': 'https://www.concertarchives.org/locations/macau-china'},
#  {'concert_date': 'May 04, 2018–May 06, 2018',
#   'concert_name': 'Landstreff Stavanger 2018',
#   'concert_link': 'https://www.concertarchives.org/concerts/landstreff-stavanger-2018',
#   'concert_venue_name': 'Landstreff Russ',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/landstreff-russ',
#   'concert_location_name': 'Stavanger, Norway',
#   'concert_location_link': 'https://www.concertarchives.org/locations/stavanger-norway'},
#  {'concert_date': 'Apr 29, 2018–Apr 30, 2018',
#   'concert_name': 'EDC China 2018',
# ...
#   'concert_location_name': 'Camboriu, Brazil',
#   'concert_location_link': 'https://www.concertarchives.org/locations/camboriu-brazil'},
#  {'concert_date': 'May 07, 2014–May 08, 2014',
#   'concert_name': 'MAGNETIC Festival - Spring Edition 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/magnetic-festival-spring-edition-2014',
#   'concert_venue_name': 'PVA Expo Praha',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/pva-expo-praha',
#   'concert_location_name': 'Prague, Czech Republic',
#   'concert_location_link': 'https://www.concertarchives.org/locations/prague-czech-republic'},
#  {'concert_date': 'May 04, 2014–May 05, 2014',
#   'concert_name': 'Electric Zoo',
#   'concert_link': 'https://www.concertarchives.org/concerts/electric-zoo--4',
#   'concert_venue_name': 'Arena Ciudad de México',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/arena-ciudad-de-mexico--9',
#   'concert_location_name': 'Ciudad de México, MX',
#   'concert_location_link': 'https://www.concertarchives.org/locations/ciudad-de-mexico-mx'},
#  {'concert_date': 'May 02, 2014–May 04, 2014',
#   'concert_name': 'Landstreffet 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/landstreffet-2014',
#   'concert_venue_name': 'Unknown Venue',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/unknown-venue-3cd880cd-449b-44ad-8179-e3267079de24',
#   'concert_location_name': 'Stavanger, Norway',
#   'concert_location_link': 'https://www.concertarchives.org/locations/stavanger-norway'},
#  {'concert_date': 'Apr 26, 2014',
#   'concert_name': '538 Koningsdag 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/538-koningsdag-2014',
#   'concert_venue_name': 'Chasséveld',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/chasseveld',
#   'concert_location_name': 'Breda, Netherlands',
#   'concert_location_link': 'https://www.concertarchives.org/locations/breda-netherlands'},
#  {'concert_date': 'Apr 26, 2014',
#   'concert_name': '538 Koningsdag',
#   'concert_link': 'https://www.concertarchives.org/concerts/538-koningsdag--3',
#   'concert_venue_name': 'Chasséveld',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/chasseveld',
#   'concert_location_name': 'Breda, Netherlands',
#   'concert_location_link': 'https://www.concertarchives.org/locations/breda-netherlands'},
#  {'concert_date': 'Apr 18, 2014–Apr 20, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--6',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 18, 2014–Apr 20, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--16',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 18, 2014–Apr 20, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--2',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014-11e3c648-e173-4caf-9b05-6ffc180c3d30',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--3',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--13',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--8',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella--90',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--18',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--4',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 11, 2014–Apr 13, 2014',
#   'concert_name': 'Coachella 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/coachella-2014--17',
#   'concert_venue_name': 'Empire Polo Club',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/empire-polo-club--3',
#   'concert_location_name': 'Indio, CA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/indio-ca'},
#  {'concert_date': 'Apr 05, 2014',
#   'concert_name': 'Martin Garrix / Melhores Do Ano',
#   'concert_link': 'https://www.concertarchives.org/concerts/martin-garrix-melhores-do-ano',
#   'concert_venue_name': 'Rosa Mota Pavilion',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/rosa-mota-pavilion',
#   'concert_location_name': 'Porto, Portugal',
#   'concert_location_link': 'https://www.concertarchives.org/locations/porto-portugal'},
#  {'concert_date': 'Mar 26, 2014',
#   'concert_name': 'Kings of Ace / Sidney Samson / Shermanology / Chocolate Puma / Ummet Ozcan / Quintino / Bassjackers / Franky Rizardo / Bobby Burns / Leroy Styles / Mitch Crown / Baggi Begovic / Billy the Kit / Jaziah / Yellow Claw / Jay Hardaway / Afrojack / Mart...',
#   'concert_link': 'https://www.concertarchives.org/concerts/kings-of-ace-sidney-samson-shermanology-chocolate-puma-ummet-ozcan-quintino-bassjackers-franky-rizardo-bobby-burns-leroy-styles-mitch-crown-baggi-begovic-billy-the-kit-jaziah-yellow-claw-jay-hardaway-afrojack-mart',
#   'concert_venue_name': 'Shelborne Wyndham Grand South Beach',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/shelborne-wyndham-grand-south-beach',
#   'concert_location_name': 'Miami, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/miami-fl'},
#  {'concert_date': 'Mar 26, 2014',
#   'concert_name': 'DVBBS / Firebeatz / Ummet Ozcan / Borgeous / Moguai / Sidney Samson / R3hab / Quintino / Martin Garrix / Yellow Claw / Oliver Heldens / Mightyfools / Armand Pena / Chris Lake / Harry Romero / Richard Grey / Michael Woods / Swanky Tunes / Plastik F...',
#   'concert_link': 'https://www.concertarchives.org/concerts/dvbbs-firebeatz-ummet-ozcan-borgeous-moguai-sidney-samson-r3hab-quintino-martin-garrix-yellow-claw-oliver-heldens-mightyfools-armand-pena-chris-lake-harry-romero-richard-grey-michael-woods-swanky-tunes-plastik-f',
#   'concert_venue_name': 'Shore Club South Beach',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/shore-club-south-beach',
#   'concert_location_name': 'Miami, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/miami-fl'},
#  {'concert_date': 'Mar 26, 2014',
#   'concert_name': 'Apster / Baggi Begovic / Bassjackers / Billy the Kit / Bobby Burns / Chocolate Puma / Franky Rizardo / Jay Hardway / Jaziah / Leroy Styles / Mitch Crown / Quintino / Ralvero / Shermanology / Sidney Samson / Ummet Ozcan / Yellow Claw / Ambush / Zaw...',
#   'concert_link': 'https://www.concertarchives.org/concerts/apster-baggi-begovic-bassjackers-billy-the-kit-bobby-burns-chocolate-puma-franky-rizardo-jay-hardway-jaziah-leroy-styles-mitch-crown-quintino-ralvero-shermanology-sidney-samson-ummet-ozcan-yellow-claw-ambush-zaw',
#   'concert_venue_name': 'Shelborne Wyndham Grand South Beach',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/shelborne-wyndham-grand-south-beach',
#   'concert_location_name': 'Miami, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/miami-fl'},
#  {'concert_date': 'Mar 24, 2014',
#   'concert_name': 'Bassjackers / Julian Jordan / Martin Garrix / Oliver Heldens / Friends at Liv',
#   'concert_link': 'https://www.concertarchives.org/concerts/bassjackers-julian-jordan-martin-garrix-oliver-heldens-friends-at-liv',
#   'concert_venue_name': 'LIV Nightclub, Fontainebleau',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/liv-nightclub-fontainebleau-b4fa4804-e137-4489-8038-94f284cae4cd',
#   'concert_location_name': 'Miami, FL',
#   'concert_location_link': 'https://www.concertarchives.org/locations/miami-fl'},
#  {'concert_date': 'Mar 13, 2014–Mar 15, 2014',
#   'concert_name': 'Future Music Festival Asia 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-asia-2014',
#   'concert_venue_name': 'Bukit Jalil National Stadium',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/bukit-jalil-national-stadium',
#   'concert_location_name': 'Kuala Lumpur, Malaysia',
#   'concert_location_link': 'https://www.concertarchives.org/locations/kuala-lumpur-malaysia'},
#  {'concert_date': 'Mar 11, 2014–Mar 15, 2014',
#   'concert_name': 'SXSW 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/sxsw-2014--3',
#   'concert_venue_name': 'Flamingo Cantina',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flamingo-cantina',
#   'concert_location_name': 'Austin, TX',
#   'concert_location_link': 'https://www.concertarchives.org/locations/austin-tx'},
#  {'concert_date': 'Mar 11, 2014–Mar 15, 2014',
#   'concert_name': 'SXSW 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/sxsw-2014--4',
#   'concert_venue_name': 'Flamingo Cantina',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flamingo-cantina',
#   'concert_location_name': 'Austin, TX',
#   'concert_location_link': 'https://www.concertarchives.org/locations/austin-tx'},
#  {'concert_date': 'Mar 10, 2014–Mar 10, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014-eb2fcae5-0200-45c2-b8bb-9226c0d9ef14',
#   'concert_venue_name': 'Adelaide Showground',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/adelaide-showground-c68cf330-ff43-4592-93dc-2b5d28ade1bf',
#   'concert_location_name': 'Adelaide, SA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/adelaide-sa'},
#  {'concert_date': 'Mar 09, 2014–Mar 09, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014--7',
#   'concert_venue_name': 'Flemington Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flemington-racecourse--10',
#   'concert_location_name': 'Melbourne, VIC',
#   'concert_location_link': 'https://www.concertarchives.org/locations/melbourne-vic'},
#  {'concert_date': 'Mar 09, 2014–Mar 09, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014',
#   'concert_venue_name': 'Flemington Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flemington-racecourse',
#   'concert_location_name': 'Melbourne',
#   'concert_location_link': 'https://www.concertarchives.org/locations/melbourne--2'},
#  {'concert_date': 'Mar 08, 2014–Mar 08, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014--5',
#   'concert_venue_name': 'Royal Randwick Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/royal-randwick-racecourse',
#   'concert_location_name': 'Sydney, NSW',
#   'concert_location_link': 'https://www.concertarchives.org/locations/sydney-nsw'},
#  {'concert_date': 'Mar 08, 2014–Mar 08, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014--8',
#   'concert_venue_name': 'Royal Randwick Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/royal-randwick-racecourse',
#   'concert_location_name': 'Sydney, NSW',
#   'concert_location_link': 'https://www.concertarchives.org/locations/sydney-nsw'},
#  {'concert_date': 'Mar 08, 2014–Mar 08, 2014',
#   'concert_name': 'Future Music Festival 2014',
#   'concert_link': 'https://www.concertarchives.org/concerts/future-music-festival-2014--3',
#   'concert_venue_name': 'Royal Randwick Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/royal-randwick-racecourse',
#   'concert_location_name': 'Sydney, NSW',
#   'concert_location_link': 'https://www.concertarchives.org/locations/sydney-nsw'},
#  {'concert_date': 'Mar 07, 2014',
#   'concert_name': 'Dada Life / Deadmau5 / Chuckie / Kaskade / Porter Robinson / Hardwell / R3hab / Baauer / Timmy Trumpet / Macklemore & Ryan Lewis / Will Sparks / Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/dada-life-deadmau5-chuckie-kaskade-porter-robinson-hardwell-r3hab-baauer-timmy-trumpet-macklemore-ryan-lewis-will-sparks-martin-garrix',
#   'concert_venue_name': 'Flemington Racecourse',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/flemington-racecourse--10',
#   'concert_location_name': 'Melbourne, VIC',
#   'concert_location_link': 'https://www.concertarchives.org/locations/melbourne-vic'},
#  {'concert_date': 'Mar 03, 2014',
#   'concert_name': 'Dada Life / Deadmau5 / Chuckie / Kaskade / Porter Robinson / Hardwell / R3hab / Baauer / Timmy Trumpet / Macklemore & Ryan Lewis / Martin Garrix',
#   'concert_link': 'https://www.concertarchives.org/concerts/dada-life-deadmau5-chuckie-kaskade-porter-robinson-hardwell-r3hab-baauer-timmy-trumpet-macklemore-ryan-lewis-martin-garrix',
#   'concert_venue_name': 'Arena Joondalup',
#   'concert_venue_link': 'https://www.concertarchives.org/venues/arena-joondalup-94199294-dcda-4d74-b169-52c5a10472aa',
#   'concert_location_name': 'Perth, WA',
#   'concert_location_link': 'https://www.concertarchives.org/locations/perth-wa--2'}]

# %% [markdown]
# ## 1.e. Convert to DataFrame and Dump to Disk

# %%
# Convert to DataFrame
df = pd.DataFrame(concert_collection)

df.head()
# Out:
#                 concert_date                                 concert_name  \
# 0  Jul 30, 2020–Aug 02, 2020                         Untold Festival 2020
# 1  Feb 23, 2020–Feb 23, 2020                       Carnaval do B.E.M 2020
# 2  Feb 22, 2020–Feb 23, 2020  Carnaval Maori 10 anos • Martin Garrix 2020
# 3               Feb 21, 2020                       Carnaval Maori 10 Anos
# 4               Feb 01, 2020                                Martin Garrix
#
#                                         concert_link  \
# 0  https://www.concertarchives.org/concerts/untol...
# 1  https://www.concertarchives.org/concerts/carna...
# 2  https://www.concertarchives.org/concerts/carna...
# 3  https://www.concertarchives.org/concerts/carna...
# 4  https://www.concertarchives.org/concerts/marti...
#
#            concert_venue_name  \
# 0                  Cluj Arena
# 1         Estádio do Mineirão
# 2            Maori Beach Club
# 3            Maori Beach Club
# 4  DAER Dayclub South Florida
#
#                                   concert_venue_link   concert_location_name  \
# 0  https://www.concertarchives.org/venues/cluj-arena    Cluj-Napoca, Romania
# 1  https://www.concertarchives.org/venues/estadio...  Belo Horizonte, Brazil
# 2  https://www.concertarchives.org/venues/maori-b...    Porto Alegre, Brazil
# 3  https://www.concertarchives.org/venues/maori-b...       Xangri-lá, Brazil
# 4  https://www.concertarchives.org/venues/daer-da...     Fort Lauderdale, FL
#
#                                concert_location_link
# 0  https://www.concertarchives.org/locations/cluj...
# 1  https://www.concertarchives.org/locations/belo...
# 2  https://www.concertarchives.org/locations/port...
# 3  https://www.concertarchives.org/locations/xang...
# 4  https://www.concertarchives.org/locations/fort...

# %%
# Dump to disk for storage and next stage in the project
df.to_excel(concert_collection_file, index=False)
